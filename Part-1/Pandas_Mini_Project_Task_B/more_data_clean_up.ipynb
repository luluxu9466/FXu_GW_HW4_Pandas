# %%
# Dependencies
import pandas as pd

# %%
# load CSV
csvfile = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
df = pd.read_csv(csvfile, low_memory = False)

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
df = df.iloc[:,[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]

# %%
# Change reading 0 and 1 to No and Yes, respectively
df = df.replace(0, "No")
df = df.replace(1, "Yes")

# %%
# Extract rows for only those who attended a bootcamp
attended_df = df.loc[df["AttendedBootcamp"] == "Yes", :]

# %%
# Create a DataFrame with two columns: One with the bootcamp name, and one with the number of respondents who went to each bootcamp.
bootcamp_name = pd.DataFrame(attended_df["BootcampName"].value_counts())
bootcamp_name.head()
bootcamp_name = bootcamp_name.reset_index()
bootcamp_name.columns = ['BootcampName', 'Number of Respondents']
bootcamp_name
# Out:
#                                           BootcampName  Number of Respondents
# 0                                     General Assembly                     90
# 1                                      Flatiron School                     54
# 2                                         Dev Bootcamp                     48
# 3                                        The Iron Yard                     40
# 4                                Prime Digital Academy                     30
# 5                                         Hack Reactor                     29
# 6                                               Turing                     27
# 7                                          App Academy                     22
# 8                                   Hackbright Academy                     22
# 9                                         Code Fellows                     21
# 10                                             Bloc.io                     21
# 11                                           Galvanize                     20
# 12                                         MakerSquare                     20
# 13                      New York Code + Design Academy                     20
# 14                                         Coding Dojo                     18
# 15                                The Firehose Project                     16
# 16   Free Code Camp is not a bootcamp - please scro...                     15
# 17                                            Epicodus                     14
# 18                                         Dev Academy                     13
# 19                                   Tech Talent South                     12
# 20                                      Makers Academy                     12
# 21                                         Coder Camps                     11
# 22                                              Codeup                     10
# 23                                         DevMountain                     10
# 24                                      Launch Academy                     10
# 25                                  Viking Code School                     10
# 26                                      Software Guild                     10
# 27                                                 Ada                      9
# 28                                           CodeaCamp                      8
# 29                                      4Geeks Academy                      8
# ..                                                 ...                    ...
# 98                                         DESIGNATION                      1
# 99                                 AngelHack Education                      1
# 100                                      Coder Foundry                      1
# 101                                           Le Wagon                      1
# 102                                      Claim Academy                      1
# 103                                           Alphappl                      1
# 104                                CodeMasters Academy                      1
# 105                                  Astro Code School                      1
# 106                                Origin Code Academy                      1
# 107                                  Data Science Dojo                      1
# 108                                  Code For Progress                      1
# 109                                  Ruby On The Beach                      1
# 110                              Academic Work Academy                      1
# 111                              Austin Coding Academy                      1
# 112                                     Base10 Academy                      1
# 113                                        TalentBuddy                      1
# 114                               Ladies Learning Code                      1
# 115                                         Code Union                      1
# 116                                       Atlanta Code                      1
# 117                                 The Data Incubator                      1
# 118                               Interface Web School                      1
# 119                                         Stackademy                      1
# 120                                          SeedPaths                      1
# 121                                            Code 42                      1
# 122                                          Academy X                      1
# 123                            Science to Data Science                      1
# 124           Launch School (formerly Tealeaf Academy)                      1
# 125                                           Betamore                      1
# 126      Microsoft Research Data Science Summer School                      1
# 127                                              codeU                      1
#
# [128 rows x 2 columns]

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
bootcamp_name = pd.DataFrame(attended_df["BootcampName"].value_counts())
bootcamp_name.head()
bootcamp_name = bootcamp_name.reset_index()
bootcamp_name.columns = ['BootcampName', 'Number of Respondents']
bootcamp_name
# Out:
#                                           BootcampName  Number of Respondents
# 0                                     General Assembly                     90
# 1                                      Flatiron School                     54
# 2                                         Dev Bootcamp                     48
# 3                                        The Iron Yard                     40
# 4                                Prime Digital Academy                     30
# 5                                         Hack Reactor                     29
# 6                                               Turing                     27
# 7                                          App Academy                     22
# 8                                   Hackbright Academy                     22
# 9                                         Code Fellows                     21
# 10                                             Bloc.io                     21
# 11                                           Galvanize                     20
# 12                                         MakerSquare                     20
# 13                      New York Code + Design Academy                     20
# 14                                         Coding Dojo                     18
# 15                                The Firehose Project                     16
# 16   Free Code Camp is not a bootcamp - please scro...                     15
# 17                                            Epicodus                     14
# 18                                         Dev Academy                     13
# 19                                   Tech Talent South                     12
# 20                                      Makers Academy                     12
# 21                                         Coder Camps                     11
# 22                                              Codeup                     10
# 23                                         DevMountain                     10
# 24                                      Launch Academy                     10
# 25                                  Viking Code School                     10
# 26                                      Software Guild                     10
# 27                                                 Ada                      9
# 28                                           CodeaCamp                      8
# 29                                      4Geeks Academy                      8
# ..                                                 ...                    ...
# 98                                         DESIGNATION                      1
# 99                                 AngelHack Education                      1
# 100                                      Coder Foundry                      1
# 101                                           Le Wagon                      1
# 102                                      Claim Academy                      1
# 103                                           Alphappl                      1
# 104                                CodeMasters Academy                      1
# 105                                  Astro Code School                      1
# 106                                Origin Code Academy                      1
# 107                                  Data Science Dojo                      1
# 108                                  Code For Progress                      1
# 109                                  Ruby On The Beach                      1
# 110                              Academic Work Academy                      1
# 111                              Austin Coding Academy                      1
# 112                                     Base10 Academy                      1
# 113                                        TalentBuddy                      1
# 114                               Ladies Learning Code                      1
# 115                                         Code Union                      1
# 116                                       Atlanta Code                      1
# 117                                 The Data Incubator                      1
# 118                               Interface Web School                      1
# 119                                         Stackademy                      1
# 120                                          SeedPaths                      1
# 121                                            Code 42                      1
# 122                                          Academy X                      1
# 123                            Science to Data Science                      1
# 124           Launch School (formerly Tealeaf Academy)                      1
# 125                                           Betamore                      1
# 126      Microsoft Research Data Science Summer School                      1
# 127                                              codeU                      1
#
# [128 rows x 2 columns]

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
recommended_df = df.loc[df["BootcampRecommend"] == "Yes", :]
recommended_df.head()

recommend_bootcamp = pd.DataFrame(recommended_df["BootcampName"].value_counts())
recommend_bootcamp.head()
recommend_bootcamp = recommend_bootcamp.reset_index()
recommend_bootcamp.columns = ['BootcampName', 'Number of Recommenders']
recommend_bootcamp
# Out:
#                                           BootcampName  Number of Recommenders
# 0                                     General Assembly                      70
# 1                                      Flatiron School                      50
# 2                                         Dev Bootcamp                      41
# 3                                        The Iron Yard                      31
# 4                                         Hack Reactor                      27
# 5                                               Turing                      26
# 6                                Prime Digital Academy                      25
# 7                                          App Academy                      20
# 8                                   Hackbright Academy                      19
# 9                                          MakerSquare                      18
# 10                                        Code Fellows                      15
# 11   Free Code Camp is not a bootcamp - please scro...                      14
# 12                      New York Code + Design Academy                      14
# 13                                The Firehose Project                      13
# 14                                         Dev Academy                      13
# 15                                      Makers Academy                      12
# 16                                             Bloc.io                      11
# 17                                            Epicodus                      11
# 18                                         Coding Dojo                      11
# 19                                           Galvanize                      11
# 20                                  Viking Code School                      10
# 21                                      Software Guild                       8
# 22                                           CodeaCamp                       8
# 23                                   Tech Talent South                       8
# 24                                         DevMountain                       8
# 25                                      Launch Academy                       8
# 26                                                 Ada                       8
# 27                                              Codeup                       6
# 28                                   Fullstack Academy                       6
# 29                                         Coder Camps                       6
# ..                                                 ...                     ...
# 86                                      Codify Academy                       1
# 87                                    CodeCraft School                       1
# 88                                     Operation Spark                       1
# 89                                            Le Wagon                       1
# 90                                        Coding House                       1
# 91                                      We Can Code IT                       1
# 92                                       Claim Academy                       1
# 93                                             Code 42                       1
# 94       Microsoft Research Data Science Summer School                       1
# 95                                   Ruby On The Beach                       1
# 96                                       Digital House                       1
# 97                                               codeU                       1
# 98                               Austin Coding Academy                       1
# 99                                      Base10 Academy                       1
# 100           Launch School (formerly Tealeaf Academy)                       1
# 101                                         tradecraft                       1
# 102                                              Metis                       1
# 103                                 The Data Incubator                       1
# 104                              Mobile Makers Academy                       1
# 105                                Origin Code Academy                       1
# 106                                         Stackademy                       1
# 107                                          SeedPaths                       1
# 108                            Science to Data Science                       1
# 109                                           V School                       1
# 110                               Ladies Learning Code                       1
# 111                                CodeMasters Academy                       1
# 112                                         Code Union                       1
# 113                                     PDX Code Guild                       1
# 114                                           Betamore                       1
# 115                                        Coder's Lab                       1
#
# [116 rows x 2 columns]

# %%
# Merge the two created data frames on the name of tbe bootcamp
merged_df = pd.merge(bootcamp_name, recommend_bootcamp, on="BootcampName")
merged_df.head()
# Out:
#             BootcampName  Number of Respondents  Number of Recommenders
# 0       General Assembly                     90                      70
# 1        Flatiron School                     54                      50
# 2           Dev Bootcamp                     48                      41
# 3          The Iron Yard                     40                      31
# 4  Prime Digital Academy                     30                      25

# %%
# Calculate percentage of each bootcamp's students who are recommenders
merged_df["% Recommended"] = merged_df["Number of Recommenders"]/ merged_df["Number of Respondents"] *100
merged_df = merged_df.sort_values(by="% Recommended", ascending=False).round(2)
merged_df["% Recommended"] = merged_df["% Recommended"].map("{:,.2f}%".format)
merged_df
# Out:
#                                       BootcampName  Number of Respondents  \
# 58                                      Dev League                      3
# 49                                     devCodeCamp                      4
# 92                               Founders & Coders                      1
# 91                                 Operation Spark                      1
# 90                                    Byte Academy                      1
# 89                                     Coder's Lab                      1
# 88                                        AcadGild                      2
# 87                                     EHD Academy                      2
# 86                               Omaha Code School                      2
# 85                            Eleven Fifty Academy                      2
# 82                               Telegraph Academy                      2
# 81                                 Codecademy Labs                      2
# 79                                  Big Nerd Ranch                      2
# 77                                    Code Platoon                      2
# 76                                   We Got Coders                      2
# 75                                   DigitalCrafts                      2
# 74                                  BoiseCodeWorks                      2
# 73                             CODEcamp Charleston                      2
# 69                                   Coder Factory                      2
# 67                                   LEARN Academy                      3
# 64                            Grace Hopper Academy                      3
# 93                                CodeCraft School                      1
# 94                                  Code Institute                      1
# 95                                     DESIGNATION                      1
# 106                                     Code Union                      1
# 114  Microsoft Research Data Science Summer School                      1
# 113                                       Betamore                      1
# 112       Launch School (formerly Tealeaf Academy)                      1
# 111                        Science to Data Science                      1
# 110                                        Code 42                      1
# ..                                             ...                    ...
# 14                                     Coding Dojo                     18
# 22                                          Codeup                     10
# 41                               CodeCore Bootcamp                      5
# 37                                      10x.org.il                      5
# 40                                   Bitmaker Labs                      5
# 30                               Startup Institute                      7
# 11                                       Galvanize                     20
# 21                                     Coder Camps                     11
# 10                                         Bloc.io                     21
# 45                                       RefactorU                      4
# 29                                  4Geeks Academy                      8
# 70                                  PDX Code Guild                      2
# 47                                    Bit Bootcamp                      4
# 50                                  Camp Code Away                      4
# 52                                       Devschool                      4
# 54                                       Codesmith                      4
# 84                           Mobile Makers Academy                      2
# 80                                   Digital House                      2
# 71                                       HackerYou                      2
# 72                                    LearningFuze                      2
# 35                                         Wyncode                      6
# 78                                   Fire Bootcamp                      2
# 83                                           Metis                      2
# 68                                        V School                      3
# 65                                  Starter League                      3
# 60                                      tradecraft                      3
# 56                                    Coding House                      3
# 55                             Zip Code Wilmington                      3
# 66                                  We Can Code IT                      3
# 46                                  Codify Academy                      4
#
#      Number of Recommenders % Recommended
# 58                        3       100.00%
# 49                        4       100.00%
# 92                        1       100.00%
# 91                        1       100.00%
# 90                        1       100.00%
# 89                        1       100.00%
# 88                        2       100.00%
# 87                        2       100.00%
# 86                        2       100.00%
# 85                        2       100.00%
# 82                        2       100.00%
# 81                        2       100.00%
# 79                        2       100.00%
# 77                        2       100.00%
# 76                        2       100.00%
# 75                        2       100.00%
# 74                        2       100.00%
# 73                        2       100.00%
# 69                        2       100.00%
# 67                        3       100.00%
# 64                        3       100.00%
# 93                        1       100.00%
# 94                        1       100.00%
# 95                        1       100.00%
# 106                       1       100.00%
# 114                       1       100.00%
# 113                       1       100.00%
# 112                       1       100.00%
# 111                       1       100.00%
# 110                       1       100.00%
# ..                      ...           ...
# 14                       11        61.11%
# 22                        6        60.00%
# 41                        3        60.00%
# 37                        3        60.00%
# 40                        3        60.00%
# 30                        4        57.14%
# 11                       11        55.00%
# 21                        6        54.55%
# 10                       11        52.38%
# 45                        2        50.00%
# 29                        4        50.00%
# 70                        1        50.00%
# 47                        2        50.00%
# 50                        2        50.00%
# 52                        2        50.00%
# 54                        2        50.00%
# 84                        1        50.00%
# 80                        1        50.00%
# 71                        1        50.00%
# 72                        1        50.00%
# 35                        3        50.00%
# 78                        1        50.00%
# 83                        1        50.00%
# 68                        1        33.33%
# 65                        1        33.33%
# 60                        1        33.33%
# 56                        1        33.33%
# 55                        1        33.33%
# 66                        1        33.33%
# 46                        1        25.00%
#
# [116 rows x 4 columns]

# %%
# Export to excel and remove index
merged_df.to_excel("output/Bootcamppart2.xlsx", index=False)
