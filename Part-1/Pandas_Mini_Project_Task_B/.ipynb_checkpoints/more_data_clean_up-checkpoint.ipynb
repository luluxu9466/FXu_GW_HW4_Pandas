# %%
# Dependencies
import pandas as pd

# %%
# load CSV
csvfile = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
df = pd.read_csv(csvfile, low_memory = False)

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
df = df.iloc[:,[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]

# %%
# Change reading 0 and 1 to No and Yes, respectively
df = df.replace(0, "No")
df = df.replace(1, "Yes")

# %%
# Extract rows for only those who attended a bootcamp
attended_df = df.loc[df["AttendedBootcamp"] == "Yes", :]

# %%
# Create a DataFrame with two columns: One with the bootcamp name, and one with the number of respondents who went to each bootcamp.
bootcamp_name = pd.DataFrame(attended_df["BootcampName"].value_counts())
bootcamp_name.head()
bootcamp_name = bootcamp_name.reset_index()
bootcamp_name.columns = ['BootcampName', 'Number of Respondents']
bootcamp_name
# Out:
#                                           BootcampName  Number of Respondents
# 0                                     General Assembly                     90
# 1                                      Flatiron School                     54
# 2                                         Dev Bootcamp                     48
# 3                                        The Iron Yard                     40
# 4                                Prime Digital Academy                     30
# 5                                         Hack Reactor                     29
# 6                                               Turing                     27
# 7                                   Hackbright Academy                     22
# 8                                          App Academy                     22
# 9                                         Code Fellows                     21
# 10                                             Bloc.io                     21
# 11                      New York Code + Design Academy                     20
# 12                                         MakerSquare                     20
# 13                                           Galvanize                     20
# 14                                         Coding Dojo                     18
# 15                                The Firehose Project                     16
# 16   Free Code Camp is not a bootcamp - please scro...                     15
# 17                                            Epicodus                     14
# 18                                         Dev Academy                     13
# 19                                      Makers Academy                     12
# 20                                   Tech Talent South                     12
# 21                                         Coder Camps                     11
# 22                                              Codeup                     10
# 23                                      Software Guild                     10
# 24                                  Viking Code School                     10
# 25                                      Launch Academy                     10
# 26                                         DevMountain                     10
# 27                                                 Ada                      9
# 28                                           CodeaCamp                      8
# 29                                      4Geeks Academy                      8
# ..                                                 ...                    ...
# 98       Microsoft Research Data Science Summer School                      1
# 99                                   Code For Progress                      1
# 100                                  Data Science Dojo                      1
# 101                               Interface Web School                      1
# 102                                         Code Union                      1
# 103                                            Code 42                      1
# 104                                          SeedPaths                      1
# 105                               Ladies Learning Code                      1
# 106                            Science to Data Science                      1
# 107                                           Le Wagon                      1
# 108                                       Byte Academy                      1
# 109                                Origin Code Academy                      1
# 110                                      Claim Academy                      1
# 111                                    Operation Spark                      1
# 112                                     Code Institute                      1
# 113                                  Ruby On The Beach                      1
# 114                                           Alphappl                      1
# 115                              Austin Coding Academy                      1
# 116                                              codeU                      1
# 117                                      Coder Foundry                      1
# 118                                 The Data Incubator                      1
# 119                                   CodeCraft School                      1
# 120                                AngelHack Education                      1
# 121                                          Academy X                      1
# 122           Launch School (formerly Tealeaf Academy)                      1
# 123                                       Atlanta Code                      1
# 124                                Montana Code School                      1
# 125                                  Astro Code School                      1
# 126                                  World Tech Makers                      1
# 127                                           Betamore                      1
#
# [128 rows x 2 columns]

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
bootcamp_name = pd.DataFrame(attended_df["BootcampName"].value_counts())
bootcamp_name.head()
bootcamp_name = bootcamp_name.reset_index()
bootcamp_name.columns = ['BootcampName', 'Number of Respondents']
bootcamp_name
# Out:
#                                           BootcampName  Number of Respondents
# 0                                     General Assembly                     90
# 1                                      Flatiron School                     54
# 2                                         Dev Bootcamp                     48
# 3                                        The Iron Yard                     40
# 4                                Prime Digital Academy                     30
# 5                                         Hack Reactor                     29
# 6                                               Turing                     27
# 7                                   Hackbright Academy                     22
# 8                                          App Academy                     22
# 9                                         Code Fellows                     21
# 10                                             Bloc.io                     21
# 11                      New York Code + Design Academy                     20
# 12                                         MakerSquare                     20
# 13                                           Galvanize                     20
# 14                                         Coding Dojo                     18
# 15                                The Firehose Project                     16
# 16   Free Code Camp is not a bootcamp - please scro...                     15
# 17                                            Epicodus                     14
# 18                                         Dev Academy                     13
# 19                                      Makers Academy                     12
# 20                                   Tech Talent South                     12
# 21                                         Coder Camps                     11
# 22                                              Codeup                     10
# 23                                      Software Guild                     10
# 24                                  Viking Code School                     10
# 25                                      Launch Academy                     10
# 26                                         DevMountain                     10
# 27                                                 Ada                      9
# 28                                           CodeaCamp                      8
# 29                                      4Geeks Academy                      8
# ..                                                 ...                    ...
# 98       Microsoft Research Data Science Summer School                      1
# 99                                   Code For Progress                      1
# 100                                  Data Science Dojo                      1
# 101                               Interface Web School                      1
# 102                                         Code Union                      1
# 103                                            Code 42                      1
# 104                                          SeedPaths                      1
# 105                               Ladies Learning Code                      1
# 106                            Science to Data Science                      1
# 107                                           Le Wagon                      1
# 108                                       Byte Academy                      1
# 109                                Origin Code Academy                      1
# 110                                      Claim Academy                      1
# 111                                    Operation Spark                      1
# 112                                     Code Institute                      1
# 113                                  Ruby On The Beach                      1
# 114                                           Alphappl                      1
# 115                              Austin Coding Academy                      1
# 116                                              codeU                      1
# 117                                      Coder Foundry                      1
# 118                                 The Data Incubator                      1
# 119                                   CodeCraft School                      1
# 120                                AngelHack Education                      1
# 121                                          Academy X                      1
# 122           Launch School (formerly Tealeaf Academy)                      1
# 123                                       Atlanta Code                      1
# 124                                Montana Code School                      1
# 125                                  Astro Code School                      1
# 126                                  World Tech Makers                      1
# 127                                           Betamore                      1
#
# [128 rows x 2 columns]

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
recommended_df = df.loc[df["BootcampRecommend"] == "Yes", :]
recommended_df.head()

recommend_bootcamp = pd.DataFrame(recommended_df["BootcampName"].value_counts())
recommend_bootcamp.head()
recommend_bootcamp = recommend_bootcamp.reset_index()
recommend_bootcamp.columns = ['BootcampName', 'Number of Recommenders']
recommend_bootcamp
# Out:
#                                           BootcampName  Number of Recommenders
# 0                                     General Assembly                      70
# 1                                      Flatiron School                      50
# 2                                         Dev Bootcamp                      41
# 3                                        The Iron Yard                      31
# 4                                         Hack Reactor                      27
# 5                                               Turing                      26
# 6                                Prime Digital Academy                      25
# 7                                          App Academy                      20
# 8                                   Hackbright Academy                      19
# 9                                          MakerSquare                      18
# 10                                        Code Fellows                      15
# 11   Free Code Camp is not a bootcamp - please scro...                      14
# 12                      New York Code + Design Academy                      14
# 13                                The Firehose Project                      13
# 14                                         Dev Academy                      13
# 15                                      Makers Academy                      12
# 16                                         Coding Dojo                      11
# 17                                           Galvanize                      11
# 18                                             Bloc.io                      11
# 19                                            Epicodus                      11
# 20                                  Viking Code School                      10
# 21                                      Software Guild                       8
# 22                                           CodeaCamp                       8
# 23                                      Launch Academy                       8
# 24                                         DevMountain                       8
# 25                                   Tech Talent South                       8
# 26                                                 Ada                       8
# 27                                              Codeup                       6
# 28                                         Coder Camps                       6
# 29                                   Fullstack Academy                       6
# ..                                                 ...                     ...
# 86       Microsoft Research Data Science Summer School                       1
# 87                                    CodeCraft School                       1
# 88                                  The Data Incubator                       1
# 89                                          Code Union                       1
# 90                                         Coder's Lab                       1
# 91                                      PDX Code Guild                       1
# 92                                 CodeMasters Academy                       1
# 93                                          tradecraft                       1
# 94                                   Ruby On The Beach                       1
# 95                                             Code 42                       1
# 96                                 AngelHack Education                       1
# 97                                     Operation Spark                       1
# 98                                 Zip Code Wilmington                       1
# 99                                       Claim Academy                       1
# 100                                          HackerYou                       1
# 101                                       Byte Academy                       1
# 102           Launch School (formerly Tealeaf Academy)                       1
# 103                                           Betamore                       1
# 104                                              Metis                       1
# 105                                           V School                       1
# 106                                      Fire Bootcamp                       1
# 107                                           Le Wagon                       1
# 108                                       Coding House                       1
# 109                                Origin Code Academy                       1
# 110                                     We Can Code IT                       1
# 111                                     Code Institute                       1
# 112                                     Starter League                       1
# 113                                          SeedPaths                       1
# 114                                     Base10 Academy                       1
# 115                              Austin Coding Academy                       1
#
# [116 rows x 2 columns]

# %%
# Merge the two created data frames on the name of tbe bootcamp
merged_df = pd.merge(bootcamp_name, recommend_bootcamp, on="BootcampName")
merged_df.head()
# Out:
#             BootcampName  Number of Respondents  Number of Recommenders
# 0       General Assembly                     90                      70
# 1        Flatiron School                     54                      50
# 2           Dev Bootcamp                     48                      41
# 3          The Iron Yard                     40                      31
# 4  Prime Digital Academy                     30                      25

# %%
# Calculate percentage of each bootcamp's students who are recommenders
merged_df["% Recommended"] = merged_df["Number of Recommenders"]/ merged_df["Number of Respondents"] *100
merged_df.sort_values(by="% Recommended", ascending=False).round(2)
merged_df["% Recommended"] = merged_df["% Recommended"].map("{:,.2f}%".format)
merged_df
# Out:
#                                           BootcampName  Number of Respondents  \
# 0                                     General Assembly                     90
# 1                                      Flatiron School                     54
# 2                                         Dev Bootcamp                     48
# 3                                        The Iron Yard                     40
# 4                                Prime Digital Academy                     30
# 5                                         Hack Reactor                     29
# 6                                               Turing                     27
# 7                                   Hackbright Academy                     22
# 8                                          App Academy                     22
# 9                                         Code Fellows                     21
# 10                                             Bloc.io                     21
# 11                      New York Code + Design Academy                     20
# 12                                         MakerSquare                     20
# 13                                           Galvanize                     20
# 14                                         Coding Dojo                     18
# 15                                The Firehose Project                     16
# 16   Free Code Camp is not a bootcamp - please scro...                     15
# 17                                            Epicodus                     14
# 18                                         Dev Academy                     13
# 19                                      Makers Academy                     12
# 20                                   Tech Talent South                     12
# 21                                         Coder Camps                     11
# 22                                              Codeup                     10
# 23                                      Software Guild                     10
# 24                                  Viking Code School                     10
# 25                                      Launch Academy                     10
# 26                                         DevMountain                     10
# 27                                                 Ada                      9
# 28                                           CodeaCamp                      8
# 29                                      4Geeks Academy                      8
# ..                                                 ...                    ...
# 86                                Eleven Fifty Academy                      2
# 87                                       Fire Bootcamp                      2
# 88                                           HackerYou                      2
# 89                                          Stackademy                      1
# 90                                         DESIGNATION                      1
# 91                                 CodeMasters Academy                      1
# 92                                   Founders & Coders                      1
# 93                                      Base10 Academy                      1
# 94                                         Coder's Lab                      1
# 95       Microsoft Research Data Science Summer School                      1
# 96                                          Code Union                      1
# 97                                             Code 42                      1
# 98                                           SeedPaths                      1
# 99                                Ladies Learning Code                      1
# 100                            Science to Data Science                      1
# 101                                           Le Wagon                      1
# 102                                       Byte Academy                      1
# 103                                Origin Code Academy                      1
# 104                                      Claim Academy                      1
# 105                                    Operation Spark                      1
# 106                                     Code Institute                      1
# 107                                  Ruby On The Beach                      1
# 108                              Austin Coding Academy                      1
# 109                                              codeU                      1
# 110                                      Coder Foundry                      1
# 111                                 The Data Incubator                      1
# 112                                   CodeCraft School                      1
# 113                                AngelHack Education                      1
# 114           Launch School (formerly Tealeaf Academy)                      1
# 115                                           Betamore                      1
#
#      Number of Recommenders % Recommended
# 0                        70        77.78%
# 1                        50        92.59%
# 2                        41        85.42%
# 3                        31        77.50%
# 4                        25        83.33%
# 5                        27        93.10%
# 6                        26        96.30%
# 7                        19        86.36%
# 8                        20        90.91%
# 9                        15        71.43%
# 10                       11        52.38%
# 11                       14        70.00%
# 12                       18        90.00%
# 13                       11        55.00%
# 14                       11        61.11%
# 15                       13        81.25%
# 16                       14        93.33%
# 17                       11        78.57%
# 18                       13       100.00%
# 19                       12       100.00%
# 20                        8        66.67%
# 21                        6        54.55%
# 22                        6        60.00%
# 23                        8        80.00%
# 24                       10       100.00%
# 25                        8        80.00%
# 26                        8        80.00%
# 27                        8        88.89%
# 28                        8       100.00%
# 29                        4        50.00%
# ..                      ...           ...
# 86                        2       100.00%
# 87                        1        50.00%
# 88                        1        50.00%
# 89                        1       100.00%
# 90                        1       100.00%
# 91                        1       100.00%
# 92                        1       100.00%
# 93                        1       100.00%
# 94                        1       100.00%
# 95                        1       100.00%
# 96                        1       100.00%
# 97                        1       100.00%
# 98                        1       100.00%
# 99                        1       100.00%
# 100                       1       100.00%
# 101                       1       100.00%
# 102                       1       100.00%
# 103                       1       100.00%
# 104                       1       100.00%
# 105                       1       100.00%
# 106                       1       100.00%
# 107                       1       100.00%
# 108                       1       100.00%
# 109                       1       100.00%
# 110                       1       100.00%
# 111                       1       100.00%
# 112                       1       100.00%
# 113                       1       100.00%
# 114                       1       100.00%
# 115                       1       100.00%
#
# [116 rows x 4 columns]

# %%
# Export to excel and remove index
merged_df.to_excel("output/Bootcamppart2.xlsx", index=False)
